# %%
import pandas as pd

import os

# %%
genuine = pd.read_csv(os.path.join(DATA_PATH, "genuine_accounts/users.csv"))

print("Genuine accounts shape:", genuine.shape)

genuine.head()
# Out:
# Genuine accounts shape: (3474, 42)
#            id               name      screen_name  statuses_count  \
# 0  1502026416    TASUKU HAYAKAWA         0918Bask            2177
# 1  2492782375              ro_or         1120Roll            2660
# 2   293212315           bearclaw        14KBBrown            1254
# 3   191839658  pocahontas farida      wadespeters          202968
# 4  3020965143           Ms Kathy  191a5bd05da04dc              82
#
#    followers_count  friends_count  favourites_count  listed_count  \
# 0              208            332               265             1
# 1              330            485              3972             5
# 2              166            177              1185             0
# 3             2248            981             60304           101
# 4               21             79                 5             0
#
#                       url lang  ... notifications  \
# 0                     NaN   ja  ...           NaN
# ...

# %%
social_spambots_1 = pd.read_csv(os.path.join(DATA_PATH, "social_spambots_1/users.csv"))
social_spambots_2 = pd.read_csv(os.path.join(DATA_PATH, "social_spambots_2/users.csv"))
social_spambots_3 = pd.read_csv(os.path.join(DATA_PATH, "social_spambots_3/users.csv"))
traditional_spambots_1 = pd.read_csv(os.path.join(DATA_PATH, "traditional_spambots_1/users.csv"))
fake_followers = pd.read_csv(os.path.join(DATA_PATH, "fake_followers/users.csv"))

print("Social spambots 1:", social_spambots_1.shape)
print("Social spambots 2:", social_spambots_2.shape)
print("Social spambots 3:", social_spambots_3.shape)
print("Traditional spambots 1:", traditional_spambots_1.shape)
print("Fake followers:", fake_followers.shape)
# Out:
# Social spambots 1: (991, 41)
# Social spambots 2: (3457, 40)
# Social spambots 3: (464, 41)
# Traditional spambots 1: (1000, 40)
# Fake followers: (3351, 38)

# %%
df.describe()
# Out:
#                  id  statuses_count  followers_count  friends_count  \
# count  1.273700e+04    12737.000000     12737.000000   12737.000000
# mean   1.170702e+09     5240.223601       670.595509     601.674492
# std    9.540452e+08    18039.397020     10028.652009    1704.464824
# min    6.780330e+05        0.000000         0.000000       0.000000
# 25%    3.317998e+08       34.000000         6.000000      42.000000
# 50%    7.275804e+08       64.000000        18.000000     240.000000
# 75%    2.354779e+09     1812.000000       297.000000     576.000000
# max    3.164942e+09   399555.000000    986837.000000   90861.000000
#
#        favourites_count  listed_count  default_profile  default_profile_image  \
# count      12737.000000  12737.000000           4404.0                   66.0
# mean        1290.638141      6.806705              1.0                    1.0
# std         6396.370455     89.234947              0.0                    0.0
# ...

# %%
df.groupby("label")[[
    "statuses_count",
    "followers_count", 
    "friends_count",
    "favourites_count",
    "listed_count"
]].mean().round(1)
# Out:
#        statuses_count  followers_count  friends_count  favourites_count  \
# label
# 0             16958.2           1393.2          633.2            4669.6
# 1               845.5            399.6          589.8              23.4
#
#        listed_count
# label
# 0              19.5
# 1               2.0

# %%
genuine["label"] = 0

social_spambots_1["label"] = 1
social_spambots_2["label"] = 1
social_spambots_3["label"] = 1
traditional_spambots_1["label"] = 1
fake_followers["label"] = 1


df = pd.concat([
    genuine,
    social_spambots_1,
    social_spambots_2,
    social_spambots_3,
    traditional_spambots_1,
    fake_followers
], ignore_index=True)

print("Combined dataset shape:", df.shape)
print("\nLabel breakdown:")

print(df["label"].value_counts())
# Out:
# Combined dataset shape: (12737, 43)
#
# Label breakdown:
# label
# 1    9263
# 0    3474
# Name: count, dtype: int64

# %%
print("Columns available:")
for col in df.columns:
    print(" -", col)
# Out:
# Columns available:
#  - id
#  - name
#  - screen_name
#  - statuses_count
#  - followers_count
#  - friends_count
#  - favourites_count
#  - listed_count
#  - url
#  - lang
#  - time_zone
#  - location
#  - default_profile
#  - default_profile_image
#  - geo_enabled
#  - profile_image_url
#  - profile_banner_url
#  - profile_use_background_image
#  - profile_background_image_url_https
#  - profile_text_color
#  - profile_image_url_https
#  - profile_sidebar_border_color
#  - profile_background_tile
#  - profile_sidebar_fill_color
#  - profile_background_image_url
#  - profile_background_color
#  - profile_link_color
#  - utc_offset
#  - is_translator
#  - follow_request_sent
#  - protected
#  - verified
#  - notifications
#  - description
#  - contributors_enabled
#  - following
#  - created_at
#  - timestamp
#  - crawled_at
#  - updated
#  - test_set_1
#  - test_set_2
#  - label

# %%
missing = df.isnull().sum()

print("Columns with missing values:")
print(missing[missing > 0])
# Out:
# Columns with missing values:
# name                                      1
# url                                   10689
# lang                                   1000
# time_zone                              8707
# location                               6541
# default_profile                        8333
# default_profile_image                 12671
# geo_enabled                           10391
# profile_banner_url                     9371
# profile_use_background_image           1405
# profile_background_image_url_https     1000
# profile_text_color                     1000
# profile_image_url_https                1000
# profile_sidebar_border_color           1000
# profile_background_tile                7316
# profile_sidebar_fill_color             1000
# profile_background_color               1000
# profile_link_color                     1000
# utc_offset                             8707
# is_translator                         12736
# follow_request_sent                   12737
# ...

# %%
DATA_PATH = "../data"

for item in os.listdir(DATA_PATH):
    print(item)
# Out:
# crowdflower_results
# fake_followers
# genuine_accounts
# social_spambots_1
# social_spambots_2
# social_spambots_3
# traditional_spambots_1
# traditional_spambots_2
# traditional_spambots_3
# traditional_spambots_4

# %%
! pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
